# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("HRDataset_clean.csv")

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df ["RecruitmentSource"]
# Out:
# 0               LinkedIn
# 1                 Indeed
# 2               LinkedIn
# 3                 Indeed
# 4          Google Search
#              ...
# 306             LinkedIn
# 307        Google Search
# 308    Employee Referral
# 309    Employee Referral
# 310             LinkedIn
# Name: RecruitmentSource, Length: 311, dtype: object

# %%
df ["RaceDesc"]
# Out:
# 0      White
# 1      White
# 2      White
# 3      White
# 4      White
#        ...
# 306    White
# 307    Asian
# 308    White
# 309    White
# 310    Asian
# Name: RaceDesc, Length: 311, dtype: object

# %%
df ["GenderID"]
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 306    1
# 307    0
# 308    0
# 309    0
# 310    0
# Name: GenderID, Length: 311, dtype: int64

# %%
df ["PerfScoreID"].unique()
# Out:
# array([4, 3, 2, 1], dtype=int64)

# %%
df ["FromDiversityJobFairID"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df ["Salary"]
# Out:
# 0       62506
# 1      104437
# 2       64955
# 3       64991
# 4       50825
#         ...
# 306     65893
# 307     48513
# 308    220450
# 309     89292
# 310     45046
# Name: Salary, Length: 311, dtype: int64

# %%
df ["Termd"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df ["Position"].unique()
# Out:
# array(['Production Technician I', 'Sr. DBA', 'Production Technician II',
#        'Software Engineer', 'IT Support', 'Data Analyst',
#        'Database Administrator', 'Enterprise Architect', 'Sr. Accountant',
#        'Production Manager', 'Accountant I', 'Area Sales Manager',
#        'Software Engineering Manager', 'BI Director',
#        'Director of Operations', 'Sr. Network Engineer', 'Sales Manager',
#        'BI Developer', 'IT Manager - Support', 'Network Engineer',
#        'IT Director', 'Director of Sales', 'Administrative Assistant',
#        'President & CEO', 'Senior BI Developer',
#        'Shared Services Manager', 'IT Manager - Infra',
#        'Principal Data Architect', 'Data Architect', 'IT Manager - DB',
#        'Data Analyst ', 'CIO'], dtype=object)

# %%
df["Position"].value_counts()
# Out:
# Position
# Production Technician I         137
# Production Technician II         57
# Area Sales Manager               27
# Production Manager               14
# Software Engineer                10
# IT Support                        8
# Data Analyst                      7
# Sr. Network Engineer              5
# Database Administrator            5
# Network Engineer                  5
# BI Developer                      4
# Senior BI Developer               3
# Administrative Assistant          3
# Sales Manager                     3
# Accountant I                      3
# Sr. DBA                           2
# IT Manager - DB                   2
# Sr. Accountant                    2
# Director of Operations            1
# Shared Services Manager           1
# Data Analyst                      1
# Data Architect                    1
# Principal Data Architect          1
# IT Manager - Infra                1
# President & CEO                   1
# Enterprise Architect              1
# ...

# %%
df["Position"] = df['Position'].replace('Data Analyst ','Data Analyst')

# %%
df["Position"].value_counts()
# Out:
# Position
# Production Technician I         137
# Production Technician II         57
# Area Sales Manager               27
# Production Manager               14
# Software Engineer                10
# IT Support                        8
# Data Analyst                      8
# Network Engineer                  5
# Sr. Network Engineer              5
# Database Administrator            5
# BI Developer                      4
# Sales Manager                     3
# Accountant I                      3
# Senior BI Developer               3
# Administrative Assistant          3
# Sr. Accountant                    2
# IT Manager - DB                   2
# Sr. DBA                           2
# President & CEO                   1
# Data Architect                    1
# Principal Data Architect          1
# IT Manager - Infra                1
# Shared Services Manager           1
# IT Director                       1
# Director of Sales                 1
# IT Manager - Support              1
# ...

# %%
df ["PositionID"].value_counts ()
# Out:
# PositionID
# 19    137
# 20     57
# 3      27
# 18     13
# 24      9
# 14      8
# 9       8
# 15      5
# 28      5
# 8       5
# 4       4
# 13      4
# 22      3
# 2       3
# 1       3
# 21      3
# 23      2
# 26      2
# 27      2
# 10      1
# 12      1
# 11      1
# 5       1
# 16      1
# 25      1
# 30      1
# 29      1
# 7       1
# 17      1
# 6       1
# Name: count, dtype: int64

# %%
df ["State"].value_counts()
# Out:
# State
# MA    276
# CT      6
# TX      3
# VT      2
# UT      1
# AZ      1
# ND      1
# OR      1
# MT      1
# NV      1
# ID      1
# KY      1
# NC      1
# FL      1
# GA      1
# CO      1
# NY      1
# PA      1
# RI      1
# NH      1
# TN      1
# IN      1
# OH      1
# CA      1
# WA      1
# AL      1
# VA      1
# ME      1
# Name: count, dtype: int64

# %%
df[['Position','PositionID']].value_counts()
# Out:
# Position                      PositionID
# Production Technician I       19            137
# Production Technician II      20             57
# Area Sales Manager            3              27
# Production Manager            18             13
# Software Engineer             24              9
# IT Support                    14              8
# Data Analyst                  9               8
# Network Engineer              15              5
# Sr. Network Engineer          28              5
# Database Administrator        8               5
# BI Developer                  4               4
# Accountant I                  1               3
# Administrative Assistant      2               3
# Senior BI Developer           22              3
# Sales Manager                 21              3
# Sr. DBA                       27              2
# Sr. Accountant                26              2
# IT Manager - DB               13              2
# BI Director                   5               1
# ...

# %%
filtered_df = [(df["PositionID"] != 18)&(df["Position"] == "Production Manager")]
print(filtered_df)
# Out:
# [0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 306    False
# 307    False
# 308    False
# 309    False
# 310    False
# Length: 311, dtype: bool]

# %%
# Normalizar los valores de la columna 'HispanicLatino'
df['HispanicLatino'] = df['HispanicLatino'].str.capitalize()

df['EmpID'] = df['EmpID'].astype('str')
df['MarriedID'] = df['MarriedID'].astype('str')
df['MaritalStatusID'] = df['MaritalStatusID'].astype('str')
df['GenderID'] = df['GenderID'].astype('str')
df['EmpStatusID'] = df['EmpStatusID'].astype('str')
df['DeptID'] = df['DeptID'].astype('str')

df['LastPerformanceReview_Date'] = pd.to_datetime(df['LastPerformanceReview_Date'])

df["Position"] = df['Position'].replace('Data Analyst ','Data Analyst')

df['DateofHire'] = pd.to_datetime(df['DateofHire'])
df['DateofTermination'] = pd.to_datetime(df['DateofTermination'])

# %%
df.shape
# Out:
# (311, 36)

# %%
df.head()
# Out:
#               Employee_Name  EmpID MarriedID MaritalStatusID GenderID  \
# 0       Adinolfi, Wilson  K  10026         0               0        1
# 1  Ait Sidi, Karthikeyan     10084         1               1        1
# 2         Akinkuolie, Sarah  10196         1               1        0
# 3              Alagbe,Trina  10088         1               1        0
# 4          Anderson, Carol   10069         0               2        0
#
#   EmpStatusID DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0           1      5            4                       0   62506  ...
# 1           5      3            3                       0  104437  ...
# 2           5      5            3                       0   64955  ...
# 3           1      5            3                       0   64991  ...
# 4           5      5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
1 - What are our best recruiting sources if we want to ensure a diverse organization?

# %%
df["RaceDesc"].value_counts()
# Out:
# RaceDesc
# White                               187
# Black or African American            80
# Asian                                29
# Two or more races                    11
# American Indian or Alaska Native      3
# Hispanic                              1
# Name: count, dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# Sex
# F     176
# M     135
# Name: count, dtype: int64

# %%
df["RecruitmentSource"].value_counts()
# Out:
# RecruitmentSource
# Indeed                     87
# LinkedIn                   76
# Google Search              49
# Employee Referral          31
# Diversity Job Fair         29
# CareerBuilder              23
# Website                    13
# Other                       2
# On-line Web application     1
# Name: count, dtype: int64

# %%
df_depsex = df.groupby('Department')['Sex'].value_counts(normalize=True).unstack().fillna(0)

# %%
print (df_depsex)
# Out:
# Sex                          F        M
# Department
# Admin Offices         0.666667  0.333333
# Executive Office      1.000000  0.000000
# IT/IS                 0.440000  0.560000
# Production            0.602871  0.397129
# Sales                 0.483871  0.516129
# Software Engineering  0.545455  0.454545

# %%
# Gráfico de barras para la distribución de género por fuente de departamento
fig1, ax1 = plt.subplots()
df_depsex.plot(kind='bar', stacked=True, ax=ax1)
ax1.set_title('Distribución de género por fuente de departamento')
ax1.set_xlabel('Departamento')
ax1.set_ylabel('Porcentaje')
ax1.legend(title='Sexo')

# %%
# Contar el número de personas contratadas desde cada fuente de reclutamiento
recruitment_source_counts = df['RecruitmentSource'].value_counts()

# Plot the number of people hired from each recruitment source
plt.figure(figsize=(10, 6))
recruitment_source_counts.plot(kind='bar', color='skyblue')
plt.title('Number of People Hired from Each Recruitment Source')
plt.xlabel('Recruitment Source')
plt.ylabel('Number of Hires')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Para visualizar la distribución actual de la diversidad en la compañía
# Histograma de GenderID
plt.subplot(1, 3, 1)
df['Sex'].value_counts().plot(kind='bar')
plt.title('Sex')
plt.xlabel('Sex')
plt.ylabel('Count')

# Histograma de RaceDesc
plt.subplot(1, 3, 3)
df['RaceDesc'].value_counts().plot(kind='bar')
plt.title('Race')
plt.xlabel('Race')
plt.ylabel('Count')

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %%
aux = df.copy()
orden_custom_filtrado =   ["On-line Web application","Employee Referral", "Website", "Other", "Diversity Job Fair","Indeed", "LinkedIn","Google Search", "CareerBuilder"]
aux['RecruitmentSource'] = pd.Categorical(aux['RecruitmentSource'], orden_custom_filtrado )
df_genderbysource = aux.groupby('RecruitmentSource')['Sex'].value_counts(normalize=True).unstack().fillna(0)
# Out:
# C:\Users\l03098250\AppData\Local\Temp\ipykernel_8856\1852585083.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_genderbysource = aux.groupby('RecruitmentSource')['Sex'].value_counts(normalize=True).unstack().fillna(0)

# %%
print (df_genderbysource)
# Out:
# Sex                             F        M
# RecruitmentSource
# On-line Web application  0.000000  1.000000
# Employee Referral        0.354839  0.645161
# Website                  0.461538  0.538462
# Other                    0.500000  0.500000
# Diversity Job Fair       0.000000  0.000000
# Indeed                   0.574713  0.425287
# LinkedIn                 0.578947  0.421053
# Google Search            0.673469  0.326531
# CareerBuilder            0.695652  0.304348

# %%
df_racebysource = df.groupby('RecruitmentSource')['RaceDesc'].value_counts(normalize=True).unstack().fillna(0)

# %%
print (df_racebysource)
# Out:
# RaceDesc                 American Indian or Alaska Native     Asian  \
# RecruitmentSource
# CareerBuilder                                    0.000000  0.086957
# Diversity Job Fair                               0.000000  0.000000
# Employee Referral                                0.000000  0.032258
# Google Search                                    0.020408  0.142857
# Indeed                                           0.011494  0.114943
# LinkedIn                                         0.013158  0.105263
# On-line Web application                          0.000000  0.000000
# Other                                            0.000000  0.000000
# Website                                          0.000000  0.076923
#
# RaceDesc                 Black or African American  Hispanic  \
# RecruitmentSource
# CareerBuilder                             0.217391  0.000000
# Diversity Job Fair                        1.000000  0.000000
# Employee Referral                         0.161290  0.000000
# ...

# %%
df_hisplatbysource = df.groupby('RecruitmentSource')['HispanicLatino'].value_counts(normalize=True).unstack().fillna(0)

# %%
print (df_hisplatbysource)
# Out:
# HispanicLatino                 No       Yes
# RecruitmentSource
# CareerBuilder            0.956522  0.043478
# Diversity Job Fair       0.758621  0.241379
# Employee Referral        0.903226  0.096774
# Google Search            0.918367  0.081633
# Indeed                   0.931034  0.068966
# LinkedIn                 0.921053  0.078947
# On-line Web application  1.000000  0.000000
# Other                    1.000000  0.000000
# Website                  0.923077  0.076923

# %%
# Configuración para gráficos más claros y grandes
plt.rcParams.update({'figure.figsize': (12, 8), 'axes.grid': True})

# %%
# Gráfico de barras para la distribución de género por fuente de contratación
fig1, ax1 = plt.subplots()
df_genderbysource.plot(kind='bar', stacked=True, ax=ax1)
ax1.set_title('Distribución de género por fuente de reclutamiento')
ax1.set_xlabel('Fuente de Reclutamiento')
ax1.set_ylabel('Percentage')
ax1.legend(title='Sexo')

# %%
# Gráfico de barras para la distribución de raza por fuente de contratación
fig2, ax2 = plt.subplots()
df_racebysource.plot(kind='bar', stacked=True, ax=ax2,)
ax2.set_title('Distribución de raza por fuente de reclutamiento')
ax2.set_xlabel('Fuente de Reclutamiento')
ax2.set_ylabel('Percentage')
ax2.legend(title='Raza')
plt.tight_layout()
plt.show()

# %%
# Gráfico de barras para la distribución de Hispanic/Latino por fuente de contratación
fig1, ax1 = plt.subplots()
df_hisplatbysource.plot(kind='bar', stacked=True, ax=ax1)
ax1.set_title('Hispanic Latino - Recruitment Source')
ax1.set_xlabel('RecruitmentSource')
ax1.set_ylabel('Percentage')
ax1.legend(title='Hispanic Latino')
